# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
# %load_ext jupyternotify

import matplotlib as mpt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as patches

import numpy as np
from scipy import optimize
import os

from JJ_data_processing import *
from JJformulas import *

#from tqdm import tqdm, tqdm_notebook
from tqdm.autonotebook import tqdm

from scipy.optimize import curve_fit

#tom add
from scipy.constants import hbar, pi, h, e, k

kB = k
γ = 0.57721566
RQ = h/4/e**2
Φ0 = h/2/e  
Δ = 2.1*kB
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The jupyternotify extension is already loaded. To reload it, use:
#   %reload_ext jupyternotify

# %%
import qcodes as qc
from qcodes.dataset.database import initialise_database
from qcodes.dataset.plotting import plot_by_id, get_data_by_id

# %%
def xy_by_id(idx):
    alldata = get_data_by_id(idx)
    
    x = alldata[0][0]['data']
    y = alldata[0][1]['data']
    
    return x,y

# %%
def extract_Isw_R0_by_id (idx):
    
    alldata = get_data_by_id(idx)
    
    Is = alldata[0][0]['data']
    Vs = alldata[0][1]['data']

        
    return extract_Isw_R0 (Is,Vs)

# %%
def populate_exps (exps, VERBOSE = False):

    texps = tqdm_notebook(exps)
    for exp in texps:

        Isws = []
        R0s = []

        if VERBOSE:
            fig, ax = plt.subplots()

        Is = []
        Vs = []

        Irs = []
        Vrs = []

        Ils = []
        Vls = []

        for i in exp['ids']:
            
            #print(i)

            I, V = xy_by_id(i)

            Tb = exp['T']

            ind_Vmax = np.argmax(I)
            ind_Vmin = np.argmin(I)

            ind_I0 = np.argmin(abs(I - 1e-12))
            ind_near0 = np.where(abs(I) < 10e-12)


    #         V_off = (V[ind_Vmax] + V[ind_Vmin])/2

    #         V_off = V[ind_I0]
            V_off = np.mean(V[ind_near0])


            V -= V_off
    #         I, V = offsetRemove(I,V, offX = 25.5e-12, offY = 35e-6)


            I, V = cut_dxdy(I, V, dx = 2e-9 ,dy = 40e-6)

    #         I = I - Iqp(  V, T = Tb, G1 = 1/20.06e3, G2 = 1/120e3, V0 = 0.35e-3 ) 

            g0 = np.where(I>0)
            l0 = np.where(I<0)

            Ir, Vr = I[g0], V[g0]
            Il, Vl = I[l0], V[l0]


            if VERBOSE:
                ax.plot(I,V, 'o')

            Isw, R0 = extract_Isw_R0 (I,V)
            Isws.append(Isw)
            R0s.append(R0)


            Is.append(I)
            Vs.append(V)

            Irs.append(Ir)
            Vrs.append(Vr)

            Ils.append(Il)
            Vls.append(Vl)



        exp ['Is' ] =  Is
        exp ['Vs' ] =  Vs

        exp ['Irs' ] =  Irs
        exp ['Vrs' ] =  Vrs

        exp ['Ils' ] =  Ils
        exp ['Vls' ] =  Vls



        exp ['Isws'] =  np.array(Isws)
        exp ['R0s' ] =  np.array(R0s )
        exp ['cos' ] =  np.array( abs(np.cos(np.pi*(exp['B'] - ZF )/(2* (FF - ZF)  )) ) )

# %%
TomDataWD = 'C:\\Users\\Tom\\Documents\\GershLab Local Stuff'

# %%
#SAMPLE = '55B1'
SAMPLE = '70B1N7'

qc.config["core"]["db_location"] = TomDataWD + '\ExdData\Experiments_{}.db'.format(SAMPLE)
#qc.config["core"]["db_location"] = TomDataWD + '\ExdData\Experiments_70B1N7.db'

# %%
def plot_by_B(exp, B, ax = None,**kw):
   
    ind =   np.argmin ( np.abs( exp['B'] - B ))
    
    I, V = xy_by_id( exp['ids'][ind] )
    
#     I = I - V/1.3e9

    if ax == None:
        fig, ax = plt.subplots()
        
    ax.plot( I, V, label = 'T = {:2.0f} mK, B = {:1.2f} mA'.format( exp['T']/1e-3, exp['B'][ind] /1e-3) , **kw)
    ax.legend()

# %%
#List of exp:
    
#    *list of run_ids

#73-173: IVC for T=45mK, Blist = np.linspace(0,2e-3,101), Vthr = 4mV

#174-228: Full IVC for T=45mK, Blist = np.linspace(0,2e-3,51), Vthr = 8mV

#229,230: Full IVC for T=80mK, Blist = [ZF,FF]

#231,232: Full IVC for T=100mK, Blist = [ZF,FF]

#233,234: Full IVC for T=125mK, Blist = [ZF,FF]

#236,237: Full IVC for T=150mK, Blist = [ZF,FF]

#238,239: Full IVC for T=175mK, Blist = [ZF,FF]

#246-297: Full IVC for T=200mK, Blist = np.linspace(1e-3, 2e-3, 51), Vthr = 4mV

#300-305: Full IVC for T=200mK, Blist = np.linspace(1e-3, 2e-3, 6), Vthr = 8mV

#306-356: Full IVC for T=300mK, Blist = np.linspace(1e-3, 2e-3, 51), Vthr = 4mV

#357-359: check full frustration periodicity

#360-410: Full IVC for T=350mK, Blist = np.linspace(1e-3, 2e-3, 51), Vthr = 4mV

#411-421: Full IVC for T=350mK, Blist = np.linspace(0e-3, 2e-3, 11), Vthr = 8mV

# %%
# blind stackexchange copy in next line:
#conn = sqlite3.connect("C:\\Users\\Tom\\Documents\\GershLab Local Stuff\\ExdData\\Experiments_70B1N7.db")

ZF =  0.004e-3
FF =  0.224e-3


dF = 0.250e-3
midF = 0.154e-3


keys  = ['ids',                  'T',          'B',                      'Vthr']



valss = [[range(105, 205+1),         45e-3,   np.linspace(ZF, ZF + 1.1*dF, 101),            4e-3],
#          [range(208, 292+1),         50e-3,   np.linspace(ZF, ZF + 1.1*dF, 101)[:-16],      4e-3],
         [range(295, 345+1),         70e-3,   np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(346, 396+1),         90e-3,   np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
#          [range(397, 447+1),        110e-3,   np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(450, 500+1),        110e-3,   np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(501, 551+1),        130e-3,   np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(552, 602+1),        150e-3,   np.linspace(ZF, ZF + 1.0*dF, 51) ,            4e-3],
         [range(603, 653+1),        170e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(654, 704+1),        190e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(705, 755+1),        210e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(758, 808+1),        230e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(809, 859+1),        250e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(860, 910+1),        270e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3],
         [range(918, 968+1),        290e-3,       np.linspace(ZF, ZF + 1.0*dF, 51) ,            3e-3]
         
#           [range(306,356+1),     300e-3,  np.linspace(0e-3, 2e-3, 51),    4e-3],
#          [range(360,410+1),     350e-3,  np.linspace(0e-3, 2e-3, 51),    4e-3],
#          [range(411,421+1),     350e-3,  np.linspace(0e-3, 2e-3, 11),    8e-3],
#          [range(422,432+1),     400e-3,  np.linspace(1e-3, 2e-3, 11),    8e-3]
        ]  
        


    
exps = [{ key : val for key, val in zip(keys, vals)  }  for vals in valss ]

populate_exps (exps, VERBOSE = False)

# %%
len(np.linspace(ZF, ZF + 1.1*dF, 101)[:-16])
# Out:
# 85

# %%
np.linspace(ZF, ZF + 1.0*dF, 51)
# Out:
# array([4.00e-06, 9.00e-06, 1.40e-05, 1.90e-05, 2.40e-05, 2.90e-05,
#        3.40e-05, 3.90e-05, 4.40e-05, 4.90e-05, 5.40e-05, 5.90e-05,
#        6.40e-05, 6.90e-05, 7.40e-05, 7.90e-05, 8.40e-05, 8.90e-05,
#        9.40e-05, 9.90e-05, 1.04e-04, 1.09e-04, 1.14e-04, 1.19e-04,
#        1.24e-04, 1.29e-04, 1.34e-04, 1.39e-04, 1.44e-04, 1.49e-04,
#        1.54e-04, 1.59e-04, 1.64e-04, 1.69e-04, 1.74e-04, 1.79e-04,
#        1.84e-04, 1.89e-04, 1.94e-04, 1.99e-04, 2.04e-04, 2.09e-04,
#        2.14e-04, 2.19e-04, 2.24e-04, 2.29e-04, 2.34e-04, 2.39e-04,
#        2.44e-04, 2.49e-04, 2.54e-04])

# %%
exp = exps[6]

I, V = plot_by_key(exp, 'cos', 1)
#I
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def Eb(I):
    return I*Φ0/(2*pi*k)

# %%
Idata0, Vdata0 = plot_by_key(exps[5],'cos',1)
Idata = Idata0[:80]*1e9
Vdata = Vdata0[:80]*1e6
def fitsinh(x,a,b):
    return a*np.sinh(b*x)
params1, params_covariance1 = curve_fit(fitsinh,Idata,Vdata) #,p0=[1e-7,1e-9]) #, x_scale = '1e-10', y_scale = '1e-6')
print('params = ' + str(params1))
print('params_covariance = ' + str(params_covariance1))
fig, ax = plt.subplots()
ax.plot(Idata,Vdata)
ax.plot(Idata,params1[0]*np.sinh(params1[1]*Idata))
# Out:
# <img src="data:image/png;base64,..." width="640">
# params = [0.23006506 5.76893809]
# params_covariance = [[ 0.00013346 -0.00080638]
#  [-0.00080638  0.00493948]]
# <img src="data:image/png;base64,..." width="640">

# %%
print(np.where(Id1 == 0))

print(Id)
#print(Id1)
#print(Id)
#print(Vd1)
#print(Vd)

#%notify
# Out:
# (array([ 0, 83], dtype=int64),)
# [ 1.0e-11  2.0e-11  3.0e-11  4.0e-11  5.0e-11  6.0e-11  7.0e-11  8.0e-11
#   9.0e-11  1.0e-10  1.1e-10  1.2e-10  1.3e-10  1.4e-10  1.5e-10  1.6e-10
#   1.7e-10  1.8e-10  1.9e-10  2.0e-10  2.1e-10  2.2e-10  2.3e-10  2.4e-10
#   2.5e-10  2.6e-10  2.7e-10  2.8e-10  2.9e-10  3.0e-10  3.1e-10  3.2e-10
#   3.3e-10  3.4e-10  3.5e-10  3.6e-10  3.7e-10  3.8e-10  3.9e-10  4.0e-10
#   4.1e-10  4.2e-10  4.3e-10  4.4e-10  4.5e-10  4.6e-10  4.7e-10  4.8e-10
#   4.9e-10  5.0e-10  5.1e-10  5.2e-10  5.3e-10  5.4e-10  5.5e-10  5.6e-10
#   5.7e-10  5.8e-10  5.9e-10  6.0e-10  6.1e-10  6.2e-10  6.3e-10  6.4e-10
#   6.5e-10  6.6e-10  6.7e-10  6.8e-10  6.9e-10  7.0e-10  7.1e-10  7.2e-10
#   7.3e-10  7.4e-10  7.5e-10  7.6e-10  7.7e-10  7.8e-10  7.9e-10  8.0e-10
#   8.1e-10  8.2e-10 -1.0e-11 -2.0e-11 -3.0e-11 -4.0e-11 -5.0e-11 -6.0e-11
#  -7.0e-11 -8.0e-11 -9.0e-11 -1.0e-10 -1.1e-10 -1.2e-10 -1.3e-10 -1.4e-10
# ...

# %%
#theta -> 0 is classical phase diff
Renv = 10
T = 0.15
I = 0.6e-9
Ej = 0.74
Ec = 0.2

Vqsmfull_single = V_qsm_full_verbose(Renv,T,Eb(I),Ej,Ec)
Vclfull = V_cl_full(Renv,T,Eb(I),Ej)
Vdiff = Vqsmfull_single - Vclfull
print('Vclfull = ' + str(Vclfull))
print('Vdiff = ' + str(Vdiff))


print('Vd example = ' + str(Vd[50]))
# Out:
# Renv = 10
# T = 0.15
# Eb = 0.014302234245253252
# Ej = 0.74
# Ec = 0.2
# beta = 6.666666666666667
# rho = 0.0015496183461641206
# Lambda = 0.01352340810959666
# theta = 0.06671548000734352
# Ejstar = 0.7349963389994492
# Tqm = 310.3685884519001
# Vqsm = 6618426151315.5
# Vclfull = 668204224396.701
# Vdiff = 5950221926918.799
# Vd example = 3.167349999999786e-07

# %%
#fit for Vqsmfull
#print(Vqsmfull)
#print(Vqsmfull[83])
def test_func(x,A,B):
    return A*np.sinh(B*x)

Id,Vd = load_by_key_IV(exps[0],'cos',1)

params, params_covariance = curve_fit(test_func,Id*10**9,Vqsmfull*10**18, p0=[1,1])
print('params = ' + str(params))
print('params_covariance = ' + str(params_covariance))
fig, ax = plt.subplots()
ax.plot(Id*1e9,Vqsmfull*1e18, label = 'Vqsmfull', marker = 'o')
ax.plot(Id*1e9,test_func(Id*1e9,params[0],params[1]),label = 'fit')
#ax.plot(Id,1e-22*np.sinh((1e10*Id)), label = 'manual guess')
ax.plot(Id*10**9,0.09*np.sinh(2.4*Id*10**9), label = 'manual test')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-795-3bb113589e97> in <module>
#       7 Id,Vd = load_by_key_IV(exps[0],'cos',1)
#       8
# ----> 9 params, params_covariance = curve_fit(test_func,Id*10**9,Vqsmfull*10**18, p0=[1,1])
#      10 print('params = ' + str(params))
#      11 print('params_covariance = ' + str(params_covariance))
#
# ~\AppData\Local\conda\conda\envs\qcodes\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     750         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     751         return_full = kwargs.pop('full_output', False)
# --> 752         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     753         popt, pcov, infodict, errmsg, ier = res
#     754         cost = np.sum(infodict['fvec'] ** 2)
# ...

# %%
def test_func2(x,A,B):
    return A*np.sinh(B*x)

test = np.linspace(-3,3,30)
test_y = np.sinh(test)

params, params_covariance = curve_fit(test_func2,test,test_y, p0=[2,7])
print('params = ' + str(params))
print('params_covariance = ' + str(params_covariance))
fig, ax = plt.subplots()
ax.plot(test,np.sinh(test), label = 'sinh test', marker = 'o')
ax.plot(test,test_func2(test,params[0],params[1]),label = 'fit')
ax.plot(test,test_y - test_func2(test,params[0],params[1]),label = 'diff')
#ax.plot(Id,1e-22*np.sinh((1e10*Id)), label = 'manual guess')
#ax.plot(Id,np.sinh(Id), label = 'manual guess')
ax.legend()
# Out:
# params = [1. 1.]
# params_covariance = [[ 7.76233302e-32 -2.85133552e-32]
#  [-2.85133552e-32  1.07053181e-32]]
# <img src="data:image/png;base64,..." width="640">

# %%
Ej/(h/2/e/(2*pi*k))
# Out:
# 3.356118993501359e-08

# %%
print(1)
np.size(exps)
# Out:
# 1
# 13

# %%
plot_by_key(exps[0],'cos',1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([ 0.00e+00,  1.00e-11,  2.00e-11,  3.00e-11,  4.00e-11,  5.00e-11,
#          6.00e-11,  7.00e-11,  8.00e-11,  9.00e-11,  1.00e-10,  1.10e-10,
#          1.20e-10,  1.30e-10,  1.40e-10,  1.50e-10,  1.60e-10,  1.70e-10,
#          1.80e-10,  1.90e-10,  2.00e-10,  2.10e-10,  2.20e-10,  2.30e-10,
#          2.40e-10,  2.50e-10,  2.60e-10,  2.70e-10,  2.80e-10,  2.90e-10,
#          3.00e-10,  3.10e-10,  3.20e-10,  3.30e-10,  3.40e-10,  3.50e-10,
#          3.60e-10,  3.70e-10,  3.80e-10,  3.90e-10,  4.00e-10,  4.10e-10,
#          4.20e-10,  4.30e-10,  4.40e-10,  4.50e-10,  4.60e-10,  4.70e-10,
#          4.80e-10,  4.90e-10,  5.00e-10,  5.10e-10,  5.20e-10,  5.30e-10,
#          5.40e-10,  5.50e-10,  5.60e-10,  5.70e-10,  5.80e-10,  5.90e-10,
#          6.00e-10,  6.10e-10,  6.20e-10,  6.30e-10,  6.40e-10,  6.50e-10,
#          6.60e-10,  6.70e-10,  6.80e-10,  6.90e-10,  7.00e-10,  7.10e-10,
# ...

# %%
print('Vd.size = ' + str(Vd.size))
print('Vd[79] = ' + str(Vd[79]))
print('Vd[-1] = ' + str(Vd[-1]))
# Out:
# Vd.size = 80
# Vd[79] = 1.7762249999999594e-06
# Vd[-1] = 1.7762249999999594e-06

# %%
#positive and negative sides separately: positive

#Trying different data

#notes: 60 ohm gives CB w/ super low V. 1 ohm gives match-ish for low T. Try more, maybe learn to 
#speed it up/cut out some of the array entries


#plotting data, fitting
Renv = 1
T = 0.03
Ej = 0.8
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)
        


Id1, Vd1 = plot_by_key(exps[0],'cos',1)

##removing zero values
#Id.remove(0)
#Vd.remove(0)
#Id = np.delete(Id1,83)
#Vd = np.delete(Vd1,83)
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))
#Id = np.delete(Id1, np.where(Vd1 == 0))
#Vd = np.delete(Vd1, np.where(Vd1 == 0))
#np.where(original_array == value_to_delete)

#progress bar
#    texps = tqdm_notebook(exps)
#    for exp in texps:

#cut it down
Id = Id[:80]
Vd = Vd[:80]
Ireduced = Id[::8]
Vreduced = Vd[::8]



#Iscaled = []
#Vscaled = []

#for currents in Ireduced:
#    Iscaled = np.append(Iscaled,currents)
#for volts in Vreduced:
#    Vscaled = np.append(Vscaled,volts)

#Tqm_d = []
#for currents in Id:
#    Eb = currents*h/2/e/(2*pi*k)
#    Tqm_d = np.append(Tqm_d, Tqm(Renv,T,Eb,Ej,Ec)[0])
#def V_qsm_full(Renv,T,Eb,Ej,Ec):
#Vfit = curve_fit(V_qsm_full(Renv,T,Eb(Id),Ej,Ec), Iscaled, Vscaled, p0=[1,1])


#def fitfunc(Ifit, Renvfit, Tfit): # Ejfit, Ecfit):
#    return V_qsm_scaled(Renvfit, Tfit, Eb(Ifit), 0.74, 0.2)
##def fitfunc(Ifit, Renvfit): # Ejfit, Ecfit):
##    return V_qsm_full(Renvfit, T, Eb(Ifit), 0.74, 0.2)


##fitfunc2 = np.vectorize(fitfunc)    
    
    
## params, params_covariance = curve_fit(fitfunc2,Iscaled,Vscaled, p0=10,bounds=(0.001,10000),
##                            ftol=0.9, xtol=0.9)
## print('params = ' + str(params))
## print('params_covariance = ' + str(params_covariance))

Vqsmfull = []
##Tqm = []
for current in Ireduced:
     Vqsmfull = np.append(Vqsmfull, V_qsm_full(Renv,T,Eb(current),Ej,Ec))
# for current in Id[:80]:
#      Tqm = np.append(Tqm, T_qm(Renv,T,Eb(current),Ej,Ec)[0])

factor = Vreduced[-1]/Vqsmfull[-1]
factor2 = np.amax(Vreduced)/np.amax(Vqsmfull)
print('Vd.size = ' + str(Vd.size))
print('Vd[-1] = ' + str(Vd[-1]))
#yeah
print('Vqsm last point = ' + str(Vqsmfull[-1])  )
print('factor = ' + str(factor))
print('factor2 = ' + str(factor2))
#fig, ax = plt.subplots()
#ax.plot(Iscaled,Vscaled, marker = 'o')
#ax.plot(Iscaled,fitfunc)
#fig1, ax1 = plt.subplots()
#ax.plot(Ireduced,Vqsmfull*factor)
#ax.plot(Id[:80],Tqm)
#ax.set_xlabel('I scaled (nA)')
#ax.set_ylabel('V scaled (nV)')
#ax.set_ylabel('Tqm')
fig1,ax1 = plt.subplots()
ax1.plot(Ireduced,Vreduced, marker = 'o')
ax1.plot(Ireduced,Vqsmfull*factor2)


#LOOKS LIKE AN h/e PROBLEM, find those factors :/

#notes: fit problems: weird scale, super long time for Vqsm, try using scale guess in fit function (look it up)


#%%notify
# Out:
# <img src="data:image/png;base64,..." width="640">
# Vd.size = 80
# Vd[-1] = 1.7762249999999594e-06
# Vqsm last point = 1.79305339252086e-08
# factor = 69.44104426524865
# factor2 = 69.44104426524865
# <img src="data:image/png;base64,..." width="640">

# %%
# just negative branch:

#positive and negative sides separately: positive

#Trying different data

#notes: 60 ohm gives CB w/ super low V. 1 ohm gives match-ish for low T. Try more, maybe learn to 
#speed it up/cut out some of the array entries


#plotting data, fitting
Renv = 1
T = 0.01
Ej = 0.74
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)
        


Id1, Vd1 = plot_by_key(exps[0],'cos',1)

##removing zero values
#Id.remove(0)
#Vd.remove(0)
#Id = np.delete(Id1,83)
#Vd = np.delete(Vd1,83)
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))
#Id = np.delete(Id1, np.where(Vd1 == 0))
#Vd = np.delete(Vd1, np.where(Vd1 == 0))
#np.where(original_array == value_to_delete)

#progress bar
#    texps = tqdm_notebook(exps)
#    for exp in texps:

#cut it down
Id = Id[-80:-1]
Vd = Vd[-80:-1]

#speed it up
Ireduced = Id[::4]
Vreduced = Vd[::4]

#test at higher currents
#extensionlength = 20
#Ireduced = np.append(Ireduced,np.linspace(-1e-9,-3e-8,extensionlength))
#Vreduced = np.append(Vreduced,np.zeros(extensionlength))



#Iscaled = []
#Vscaled = []

#for currents in Ireduced:
#    Iscaled = np.append(Iscaled,currents)
#for volts in Vreduced:
#    Vscaled = np.append(Vscaled,volts)

#Tqm_d = []
#for currents in Id:
#    Eb = currents*h/2/e/(2*pi*k)
#    Tqm_d = np.append(Tqm_d, Tqm(Renv,T,Eb,Ej,Ec)[0])
#def V_qsm_full(Renv,T,Eb,Ej,Ec):
#Vfit = curve_fit(V_qsm_full(Renv,T,Eb(Id),Ej,Ec), Iscaled, Vscaled, p0=[1,1])


#def fitfunc(Ifit, Renvfit, Tfit): # Ejfit, Ecfit):
#    return V_qsm_scaled(Renvfit, Tfit, Eb(Ifit), 0.74, 0.2)
##def fitfunc(Ifit, Renvfit): # Ejfit, Ecfit):
##    return V_qsm_full(Renvfit, T, Eb(Ifit), 0.74, 0.2)


##fitfunc2 = np.vectorize(fitfunc)    
    
     
## params, params_covariance = curve_fit(fitfunc2,Iscaled,Vscaled, p0=10,bounds=(0.001,10000),
##                            ftol=0.9, xtol=0.9)
## print('params = ' + str(params))
## print('params_covariance = ' + str(params_covariance))

Vqsmfull = []
##Tqm = []
for current in Ireduced:
     Vqsmfull = np.append(Vqsmfull, V_qsm_full(Renv,T,Eb(current),Ej,Ec))
# for current in Id[:80]:
#      Tqm = np.append(Tqm, T_qm(Renv,T,Eb(current),Ej,Ec)[0])


#factor2 = np.amin(Vreduced)/np.amin(Vqsmfull)
offset = np.amax(Vreduced)#-np.amax(Vqsmfull)
factor = ((-1*offset + np.amin(Vreduced))/np.amin(Vqsmfull))
print('Vd.size = ' + str(Vd.size))
print('Vd[-1] = ' + str(Vd[-1]))
#yeah
print('Vqsm last point = ' + str(Vqsmfull[-1])  )
print('factor = ' + str(factor))
#print('factor2 = ' + str(factor2))
print('offset = ' + str(offset))
fig, ax = plt.subplots()
ax.plot(Ireduced,Vreduced, marker = 'o')
#ax.plot(Iscaled,fitfunc)
#fig1, ax1 = plt.subplots()
ax.plot(Ireduced,Vqsmfull*factor+offset)
#ax.plot(Id[:80],Tqm)
#ax.set_xlabel('I scaled (nA)')
#ax.set_ylabel('V scaled (nV)')
#ax.set_ylabel('Tqm')
#fig1,ax1 = plt.subplots()
#ax1.plot(Ireduced,Vreduced, marker = 'o')
#ax1.plot(Ireduced,Vqsmfull*factor2)


#LOOKS LIKE AN h/e PROBLEM, find those factors :/

#notes: fit problems: weird scale, super long time for Vqsm, try using scale guess in fit function (look it up)


#%%notify
# Out:
# <img src="data:image/png;base64,..." width="640">
# Vd.size = 79
# Vd[-1] = -1.5572549999999692e-06
# Vqsm last point = -4.46785290277612e-47
# factor = 3.4784717263952943e+40
# offset = 2.8228499999994033e-07
# <img src="data:image/png;base64,..." width="640">

# %%
#cleanup

#positive and negative sides separately: positive


#plotting data, fitting
Renv = 1
T = 0.01
Ej = 0.74
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)
        

#Id1, Vd1 = plot_by_key(exps[0],'cos',1)
Id1, Vd1 = load_by_key_IV(exps[0],'cos',1)

##removing zero values
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))

#cut it down
Id = Id[:80]
Vd = Vd[:80]
Ireduced = Id[::3]
Vreduced = Vd[::3]


Vqsmfull = []

for current in Ireduced:
     Vqsmfull = np.append(Vqsmfull, V_qsm_full(Renv,T,Eb(current),Ej,Ec))


offset = np.amin(Vreduced) #-np.amin(Vqsmfull)
factor = np.amax(Vreduced)/np.amax(Vqsmfull) #+offset)
fig1,ax1 = plt.subplots()
ax1.plot(Ireduced,Vreduced, marker = 'o')
ax1.plot(Ireduced,Vqsmfull*factor + offset) #+ offset)

print('Vd.size = ' + str(Vd.size))
print('Vd[-1] = ' + str(Vd[-1]))
print('Vqsm last point = ' + str(Vqsmfull[-1])  )
print('factor = ' + str(factor))
print('offset = ' + str(offset)) 

#need to understand Tqm better, big surprise...
# Out:
# <img src="data:image/png;base64,..." width="640">
# Vd.size = 80
# Vd[-1] = 1.7762249999999594e-06
# Vqsm last point = 1.0271456982461098e-47
# factor = 1.54477110959954e+41
# offset = 1.1248500000004234e-07

# %%
#cleanup

#positive and negative sides separately: positive


#plotting data, fitting
Renv = 1
T = 0.016
Ej = 0.8
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)
        

#Id1, Vd1 = plot_by_key(exps[0],'cos',1)
Id1, Vd1 = load_by_key_IV(exps[0],'cos',1)

##removing zero values
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))

#cut it down
Id = Id[-80:-1]
Vd = Vd[-80:-1]
Ireduced = Id[::4]
Vreduced = Vd[::4]


Vqsmfull = []

for current in Ireduced:
     Vqsmfull = np.append(Vqsmfull, V_qsm_full(Renv,T,Eb(current),Ej,Ec))

factor = np.amin(Vreduced)/np.amin(Vqsmfull)
offset = np.amax(Vreduced)#-np.amax(Vqsmfull)
fig1,ax1 = plt.subplots()
ax1.plot(Ireduced,Vreduced, marker = 'o')
ax1.plot(Ireduced,Vqsmfull*factor+offset)

print('Vd.size = ' + str(Vd.size))
print('Vd[-1] = ' + str(Vd[-1]))
print('Vqsm last point = ' + str(Vqsmfull[-1])  )
print('factor = ' + str(factor))
print('offset = ' + str(offset))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Vd.size = 79
# Vd[-1] = -1.5572549999999692e-06
# Vqsm last point = -1.853420539435282e-27
# factor = 6.862150132357794e+20
# offset = 2.8228499999994033e-07

# %%
#investigating Tqm etc
Renv = 1
T = 0.016
Ej = 0.8
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)
        

#Id1, Vd1 = plot_by_key(exps[0],'cos',1)
Id1, Vd1 = load_by_key_IV(exps[0],'cos',1)

##removing zero values
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))

#cut it down
Id = Id[:80]
Vd = Vd[:80]
Ireduced = Id[::8]
Vreduced = Vd[::8]


Tqm = []
Tqm_error = []

for current in Ireduced:
    Tqmloop = T_qm(Renv,T,Eb(current),Ej,Ec)
    Tqm = np.append(Tqm, Tqmloop[0])
    Tqm_error = np.append(Tqm_error,Tqmloop[1])
    
#print(Tqm)
fig,ax = plt.subplots()
ax.plot(Ireduced,Tqm)

temps = np.linspace(0.01,0.1,20)
current = 5e-9
Tqm1 = []
Tqm_error1 = []

for temp in temps:
    Tqmloop1 = T_qm(Renv,temp,Eb(current),Ej,Ec)
    Tqm1 = np.append(Tqm1, Tqmloop1[0])
    Tqm_error1 = np.append(Tqm_error1,Tqmloop1[1])

fig,ax = plt.subplots()
ax.plot(temps,Tqm1)
ax.set_yscale('log')

print(Tqm1)

# def fitfunc(Ifit, Renvfit,Tfit): # Ejfit, Ecfit):
#     return V_qsm_full(Renvfit, T, Eb(Ifit), 0.74, 0.2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [7.97435572e+51 6.09681516e+34 1.06864295e+26 5.24155964e+20
#  1.45081881e+17 4.11593002e+14 5.04664948e+12 1.64855070e+11
#  1.07134891e+10 1.14925624e+09 1.79610851e+08 3.75009408e+07
#  9.83133405e+06 3.09218062e+06 1.12758772e+06 4.64414407e+05
#  2.11684349e+05 1.05079290e+05 5.60795432e+04 3.18440858e+04]

# %%
print(Ireduced)
# Out:
# [1.0e-11 9.0e-11 1.7e-10 2.5e-10 3.3e-10 4.1e-10 4.9e-10 5.7e-10 6.5e-10
#  7.3e-10]

# %%
print(Eb(Ireduced))
# Out:
# [0.00023837 0.00214534 0.0040523  0.00595926 0.00786623 0.00977319
#  0.01168016 0.01358712 0.01549409 0.01740105]

# %%
beta = 1/T
rho = Renv/RQ
Lambda = 2*rho *(γ + 2*pi**2*rho/(beta*Ec) + ψ(beta*Ec/(2*pi**2*rho)))
theta = Lambda*beta*Ej
Ejstar = Ej*(1-Lambda/2)

print('rho = ' + str(rho))
print('Lambda = ' + str(Lambda))
print('theta = ' + str(theta))
print('Ejstar = ' + str(Ejstar))
# Out:
# rho = 0.00015496183461641207
# Lambda = 0.002756086540306348
# theta = 0.1378043270153174
# Ejstar = 0.7988975653838775

# %%
print(Lambda)
#print(beta*Ec*pi**2/3)
print(ψ(beta*Ec/(2*pi**2*rho)))
print((2*pi**2*rho/(beta*Ec)))
print(2*rho)
print((γ + 2*pi**2*rho/(beta*Ec)))
print(theta)
# Out:
# 0.002756086540306348
# 8.315331033744433
# 0.0002447059207889635
# 0.00030992366923282414
# 0.577460365920789
# 0.1378043270153174

# %%
Renv = 1
T = 0.016
Ej = 0.8
Ec = 0.2
I = 1e-9
print(T_qm(Renv,T,Eb(I),Ej,Ec))
print(Eb(I))
# Out:
# (3.987047110690245e+39, 7.443680355262888e+29)
# 0.023837057075422087

# %%
V_qsm_full(Renv,T,Eb(I),Ej,Ec)
# Out:
# 3.2645798142796906e-06

# %%
T_qm_test(Renv,T,Eb(I),Ej,Ec)
# Out:
# (0.9599844464234781, 1.4749986444267957e-08)

# %%
integrate.dblquad(lambda phi,phip: np.exp(-beta*Eb(I)*phi)*np.exp(-2*np.cos(phip)*np.sin(phi/2))*(1-np.sin(phip-phi/2))*np.exp(2*np.sin(phip)*np.sin(phi/2)*(1 + 1*np.cos(phip)*np.cos(phi/2))), 0, 2*pi, lambda phip: 0, lambda phip: 2*pi)
# Out:
# (3.800465538383755, 1.4221063541561012e-08)

# %%
beta*Ejstar
# Out:
# 49.93109783649234

# %%
beta
# Out:
# 62.5

# %%
#EJSTAR IS THE PROBLEM BECAUSE IT MAKES AN EXP HUGE....WHAT DO

# %%
print(V_qsm_full(Renv, T, Eb(1e-9), 0.74, 0.2))
print(fitfunc)
print(np.vectorize(fitfunc))
# Out:
# 3.1653945657980353e-24
# <function fitfunc at 0x000002605092AF28>
# ...

# %%
Renv = 0.001
T = 0.03
Ej = 0.8
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)
        

#Id1, Vd1 = plot_by_key(exps[0],'cos',1)
Id1, Vd1 = load_by_key_IV(exps[0],'cos',1)

##removing zero values
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))

#cut it down
Id = Id[:80]
Vd = Vd[:80]
Ireduced = Id[::8]
Vreduced = Vd[::8]

Vtest = V_qsm1(Renv,T,Eb(1e-8),Ej,Ec)
print(Vtest)
print(Eb(Vtest[1]))
print(Vtest[5])
print(1-Vtest[5]**2)
print((np.sqrt(1-Vtest[5]**2))**(3/2)/(3*Vtest[5]**2))
print(Ej/T)
print(Vtest[3])
# Out:
# (3.455730521813167e-77, 3.356118993501359e-08, 4.702104852859453e-06, 0.00012538946274291875, 0.23837057075422086, 0.29796321344277604)
# 0.8000000000000002
# 0.29796321344277604
# 0.9112179234348547
# 3.501629051502864
# 26.666666666666668
# 0.00012538946274291875

# %%
VTqm = []
Renv = 0.1
T = 0.03
Ej = 0.8
Ec = 0.2

def Eb(I):
    return I*Φ0/(2*pi*k)



for currents in Id[:80]:
    #VTqm = np.append(VTqm, (Renv/RQ)*pi/((1/T)*e)*(1-np.exp(-2*pi*(1/T)*Eb(I))))
    VTqm = np.append(VTqm, 1-np.exp(-2*pi*(1/T)*Eb(currents)))
    
fig,ax = plt.subplots()
ax.plot(Id[:80],VTqm)
print(VTqm)
print(Id[1])
print(Id[78])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0.04869848 0.09502543 0.13909632 0.18102102 0.22090406 0.25884485
#  0.29493798 0.32927343 0.3619368  0.39300951 0.42256903 0.45068904
#  0.47743965 0.50288755 0.52709617 0.55012587 0.57203406 0.59287535
#  0.61270171 0.63156255 0.64950489 0.66657347 0.68281084 0.69825747
#  0.71295187 0.72693068 0.74022874 0.75287921 0.76491362 0.77636197
#  0.7872528  0.79761327 0.8074692  0.81684515 0.82576452 0.83424952
#  0.84232132 0.85000003 0.8573048  0.86425384 0.87086447 0.87715318
#  0.88313563 0.88882675 0.89424072 0.89939104 0.90429054 0.90895145
#  0.91338537 0.91760337 0.92161596 0.92543315 0.92906444 0.93251889
#  0.93580512 0.93893132 0.94190527 0.94473439 0.94742574 0.94998603
#  0.95242164 0.95473863 0.95694279 0.95903961 0.96103432 0.96293189
#  0.96473705 0.9664543  0.96808793 0.969642   0.97112039 0.97252678
#  0.97386468 0.97513743 0.9763482  0.97750001 0.97859572 0.97963808
#  0.98062968 0.98157298]
# 2e-11
# ...

# %%
print(np.exp(-2*pi*Eb(Id[1])/T))
# Out:
# 0.9049745735620337

# %%
#testing larger range of currents


#plotting data, fitting
Renv = 1
T = 0.005
Ej = 0.03
Ec = 0.01

def Eb(I):
    return I*Φ0/(2*pi*k)
        

#Id1, Vd1 = plot_by_key(exps[0],'cos',1)
Id1, Vd1 = load_by_key_IV(exps[0],'cos',1)

# ##removing zero values
Id = np.delete(Id1, np.where(Id1 == 0))
Vd = np.delete(Vd1, np.where(Id1 == 0))

# #cut it down
Id = Id[:101]
Vd = Vd[:101]
Ireduced = Id[::3]
Vreduced = Vd[::3]


#Ireduced1 = np.linspace(1e-11,0.035e-7,34)
Ireduced1 = Ireduced

Vqsmfull = []

for current in Ireduced1:
     Vqsmfull = np.append(Vqsmfull, V_qsm_full(Renv,T,Eb(current),Ej,Ec))


offset = np.amin(Vreduced) #-np.amin(Vqsmfull)
factor = np.amax(Vreduced)/V_qsm_full(Renv,T,Eb(np.amax(Ireduced)),Ej,Ec)  #np.amax(Vqsmfull) #+offset)
fig1,ax1 = plt.subplots()
ax1.plot(Ireduced,Vreduced, marker = 'o')
ax1.plot(Ireduced1,Vqsmfull*factor + offset) #+ offset)

print('Vd[-1] = ' + str(Vd[-1]))
print('Vqsm last point = ' + str(Vqsmfull[-1])  )
print('factor = ' + str(factor))
print('offset = ' + str(offset)) 
print(Ej/(Φ0/(2*pi*k)))
print(Ireduced)

#need to understand Tqm better, big surprise...
#why so volatile? check theory?
#so far this may be an exercise in "anything can be fit to anything if you try hard enough"
# Out:
# <img src="data:image/png;base64,..." width="640">
# Vd[-1] = 5.04578499999997e-06
# Vqsm last point = 2518099033887.077
# factor = 1.9163483783046585e-18
# offset = 1.1248500000004234e-07
# 1.2585446225630092e-09
# [1.0e-11 4.0e-11 7.0e-11 1.0e-10 1.3e-10 1.6e-10 1.9e-10 2.2e-10 2.5e-10
#  2.8e-10 3.1e-10 3.4e-10 3.7e-10 4.0e-10 4.3e-10 4.6e-10 4.9e-10 5.2e-10
#  5.5e-10 5.8e-10 6.1e-10 6.4e-10 6.7e-10 7.0e-10 7.3e-10 7.6e-10 7.9e-10
#  8.2e-10 8.5e-10 8.8e-10 9.1e-10 9.4e-10 9.7e-10 1.0e-09]
