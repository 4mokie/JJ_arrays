# %% [markdown]
# ## Libs

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.display import display, HTML

import numpy as np
import pandas as pd
# import itables.interactive #worth to install for pd pretty printing
# from itables import show
pd.set_eng_float_format(accuracy=1, use_eng_prefix=True)

import matplotlib.pyplot as plt

# import sys 
# sys.path.append('../../../2JJCalculator/JJcalculator')

# from JJcalc import *
import JJformulas as jjf
from JJ_data_processing import eng_string
# Out:
# D:\anaconda\lib\site-packages\qcodes\dataset\database.py:13: UserWarning: The module `qcodes.dataset.database` is deprecated.
# Public features are available at the import of `qcodes`.
# Private features are available in `qcodes.dataset.sqlite.*` modules.
#   warnings.warn('The module `qcodes.dataset.database` is deprecated.\n'

# %% [markdown]
# ## Scripts

# %%
def make_link(dev_name):
    
    folder = dev_name.split('N')[0]
    
#     path = "http://localhost:8888/notebooks/JJ_arrays/{}/{}_logbook.ipybn".format(folder,dev_name)
    path = "./{}/{}_logbook.ipybn".format(folder,dev_name)
    
    return '<a target="_blank" href={}>{}</a>'.format(path,dev_name)


def link_if_measd(df):
    
    meas_devs = df.loc[df['status'] == 'measd'].index
    rename_dict = { dev : make_link(dev) for dev in meas_devs }
    df = df.rename( index  = rename_dict )
    return df

def val_to_str(x):
    if type(x) in [float, int] :
        if  abs (x) > 999 or abs (x) < 1:
            return f'{x:3.2e}'
        else:
            return f'{x:3.1f}'
    
    return x
    
    
def show(df, sort = None, find = None, which = 'all'):
    
    cdf = df.copy()
    cdf = link_if_measd(cdf)
#     cdf = cdf.applymap( val_to_str ) 
#     cdf = cdf.applymap( lambda x : eng_string(x, si = False) ) 

#     sft = ft.sort_values(by=['Isw']).filter(like = 'D', axis = 'index')

    if sort is not None:
        cdf = cdf.sort_values(by=[sort])

    if find is not None:
        cdf = cdf.filter(like = find, axis = 'index')
        
    if which is not 'all':
        cdf = cdf[which]
    
    display(HTML(cdf.to_html(escape=False)))

# %%
def calc_jj_param(df, params = None):

    
    default_params = ['R', 'Ej', 'Ec', 'Iab' , 'wp']
    
    Rn  = df['Rn_tot']/df['#ser']
    A   = df['Ajj']
    
    Cjj = jjf.Cjj( A )
    Ec  = jjf.Ec(Cjj)/2
    
    Ej  =  jjf.EJ_AB( Rn )
    Iab =  jjf.Ic( Rn )
    
    wp  = jjf.wpK(Ej, Ec)
    
    if params is None:
        params = default_params
    
    calc_params = { k:v for k,v in locals().items() if k in params }
    
    return calc_params

# %% [markdown]
# # Data load

# %% [markdown]
# ## by hands

# %%
keys =    [             'Vo_tot', 'Rn_tot',   'Isw' , 'RoZF' , 'RoFF' , '#ser', '#par', 'dsgn',         'Ajj',  'status' ]
# unit =   [                 'V',   'ohm',     'A' ,  'ohm' ,  'ohm' ,   'ea',   'ea',     '',            'm^2', 'measd']
lst  =    {'D053N2'    : [1.610e-3,   9.3e3,    9e-8 ,  np.nan,  np.nan,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D055B1N9'  : [1.675e-3, 1.152e5, 1.53e-10, 1.006e6, 6.668e8,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D059B6N3'  : [1.875e-3, 8.438e4, 1.98e-9 , 7.883e4, 2.591e7,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D059B0N1'  : [2.178e-4, 8.756e3,  3.9e-9 , 1.314e3, 1.650e9,     2 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D059BBN2'  : [1.385e-3, 1.754e6,  3.2e-13, 2.367e8, 9.032e8,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D062B3N2'  : [2.495e-3, 9.935e5,  2.1e-11, 4.319e6, 8.931e8,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D060B2N6'  : [3.345e-3, 6.647e5,  1.2e-12, 2.292e7, 9.587e8,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D060B2N2'  : [3.186e-4, 1.199e5, 2.68e-12, 2.909e7, 9.209e8,     4 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D063BAN6_b': [5.010e-3, 5.942e5,  2.0e-11, 7.715e6, 9.350e8,    30 ,      2,  'x_s',        0.04e-12, 'fabd' ],
           'D063BAN6_a': [3.070e-3, 5.859e5,  2.2e-11, 2.650e5, 1.380e7,    30 ,      2,  'x_s',           4e-12, 'fabd' ],
           'D066B8N5_b': [1.720e-3, 6.613e4,  5.4e-9 , 8.510e2, 1.463e8,    30 ,      2,  'x_s',        0.04e-12, 'fabd' ],
           'D070B1N0'  : [  np.nan, 1.682e5,  1.6e-10, 2.373e4,  np.nan,    15 ,      2,  'x_L',           4e-12, 'measd'],
           'D079N6'    : [1.645e-4, 1.458e3, 1.37e-7 ,  2.20e0,  np.nan,     1 ,      2,  'x_L',        3.74e-12, 'measd'],
           'D079N5'    : [2.021e-3, 2.335e4,  5.6e-9 , -3.07e2,  np.nan,    15 ,      2,  'x_L',        3.74e-12, 'measd'],
           'D074N4'    : [1.972e-3, 1.350e4,  9.0e-9 ,  1.00e0,  np.nan,     9 ,      2,  'x_L',        2.25e-12, 'measd'],
           'D078N0'    : [1.931e-3, 2.542e5, 3.71e-11,  1.00e4,  np.nan,    15 ,      2,  'x_L',           4e-12, 'measd'],
           'D078N5'    : [9.685e-5, 1.670e4,  8.0e-10,  1.00e5,  np.nan,     1 ,      2,  'x_L',           4e-12, 'fabd' ],
           'D059BBN1'  : [   1e-99,   745e3,  0.6e-12,   240e6,  np.nan,    30 ,      2,  'x_L', 2.00 * 2.00e-12, 'fabd' ],
           'D059BBN2_n': [   1e-99,  1950e3,   np.nan,  np.nan,  np.nan,    30 ,      2,  'x_L', .150 * .150e-12, 'fabd' ],
           'D059BBN8'  : [   1e-99,  1780e3, 0.75e-12,    50e6,  np.nan,    30 ,      2,  'x_L', 2.00 * 2.00e-12, 'fabd' ]}


full_table = pd.DataFrame.from_dict(lst, orient='index', columns = keys )

full_table.to_excel("chain table.xlsx")

ft = full_table
full_table
# Out:
#             Vo_tot  Rn_tot     Isw    RoZF    RoFF  #ser  #par dsgn    Ajj  \
# D053N2        1.6m    9.3k   90.0n     NaN     NaN    20     2  Fin  40.0f
# D055B1N9      1.7m  115.2k  153.0p    1.0M  666.8M    20     2  Fin  40.0f
# D059B6N3      1.9m   84.4k    2.0n   78.8k   25.9M    20     2  Fin  40.0f
# D059B0N1    217.8u    8.8k    3.9n    1.3k    1.6G     2     2  Fin  40.0f
# D059BBN2      1.4m    1.8M  320.0f  236.7M  903.2M    20     2  Fin  40.0f
# D062B3N2      2.5m  993.5k   21.0p    4.3M  893.1M    20     2  Fin  40.0f
# D060B2N6      3.3m  664.7k    1.2p   22.9M  958.7M    20     2  Fin  40.0f
# D060B2N2    318.6u  119.9k    2.7p   29.1M  920.9M     4     2  Fin  40.0f
# D063BAN6_b    5.0m  594.2k   20.0p    7.7M  935.0M    30     2  x_s  40.0f
# D063BAN6_a    3.1m  585.9k   22.0p  265.0k   13.8M    30     2  x_s   4.0p
# D066B8N5_b    1.7m   66.1k    5.4n   851.0  146.3M    30     2  x_s  40.0f
# ...

# %% [markdown]
# ## from excel

# %%
full_table = pd.read_excel("chain table.xlsx")

# %% [markdown]
# # Add new batch
#
# If we fabricated a new sample and want to add the info about all sites to the database

# %%
keys =    [             'Vo_tot', 'Rn_tot',   'Isw' , 'RoZF' , 'RoFF' , '#ser', '#par', 'dsgn',         'Ajj', 'status' ]

lst  =    {'D0xxN1'  : [np.nan,       1e3,    np.nan, np.nan,  np.nan,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D0xxN2'  : [np.nan,       1e5,    np.nan, np.nan,  np.nan,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D0xxN3'  : [np.nan,       1e4,    np.nan, np.nan,  np.nan,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D0xxN4'  : [np.nan,       1e3,    np.nan, np.nan,  np.nan,     2 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D0xxN5'  : [np.nan,       1e6,    np.nan, np.nan,  np.nan,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ],
           'D0xxN6'  : [np.nan,       1e5,    np.nan, np.nan,  np.nan,    20 ,      2,  'Fin',        0.04e-12, 'fabd' ]}

new_sample = pd.DataFrame.from_dict(lst, orient='index', columns = keys )

# %%
ft = ft.append(new_sample)

ft.to_excel("chain table.xlsx")

# %% [markdown]
# # Calculate jj parameters

# %%
calc_params = calc_jj_param(ft)
ft = ft.assign(**calc_params)
ft
# Out:
#             Vo_tot  Rn_tot     Isw    RoZF    RoFF  #ser  #par dsgn    Ajj  \
# D053N2        1.6m    9.3k   90.0n     NaN     NaN    20     2  Fin  40.0f
# D055B1N9      1.7m  115.2k  153.0p    1.0M  666.8M    20     2  Fin  40.0f
# D059B6N3      1.9m   84.4k    2.0n   78.8k   25.9M    20     2  Fin  40.0f
# D059B0N1    217.8u    8.8k    3.9n    1.3k    1.6G     2     2  Fin  40.0f
# D059BBN2      1.4m    1.8M  320.0f  236.7M  903.2M    20     2  Fin  40.0f
# D062B3N2      2.5m  993.5k   21.0p    4.3M  893.1M    20     2  Fin  40.0f
# D060B2N6      3.3m  664.7k    1.2p   22.9M  958.7M    20     2  Fin  40.0f
# D060B2N2    318.6u  119.9k    2.7p   29.1M  920.9M     4     2  Fin  40.0f
# D063BAN6_b    5.0m  594.2k   20.0p    7.7M  935.0M    30     2  x_s  40.0f
# D063BAN6_a    3.1m  585.9k   22.0p  265.0k   13.8M    30     2  x_s   4.0p
# D066B8N5_b    1.7m   66.1k    5.4n   851.0  146.3M    30     2  x_s  40.0f
# ...

# %% [markdown]
# # Make pretty table
#
# clickable label if measured

# %%
show(ft, 
     which = 'all',
     sort = 'Isw', 
     find = 'D07' 
     )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Vo_tot</th>
#       <th>Rn_tot</th>
#       <th>Isw</th>
#       <th>RoZF</th>
#       <th>RoFF</th>
#       <th>#ser</th>
#       <th>#par</th>
#       <th>dsgn</th>
#       <th>Ajj</th>
#       <th>status</th>
#       <th>Iab</th>
#       <th>Ej</th>
#       <th>Ec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a target="_blank" href=./D078/D078N0_logbook.ipybn>D078N0</a></th>
#       <td>1.9m</td>
#       <td>254.2k</td>
#       <td>37.1p</td>
#       <td>10.0k</td>
#       <td>NaN</td>
#       <td>15</td>
#       <td>2</td>
#       <td>x_L</td>
#       <td>4.0p</td>
#       <td>measd</td>
#       <td>16.8n</td>
#       <td>399.8m</td>
#       <td>2.3m</td>
#     </tr>
#     <tr>
#       <th><a target="_blank" href=./D070B1/D070B1N0_logbook.ipybn>D070B1N0</a></th>
#       <td>NaN</td>
#       <td>168.2k</td>
#       <td>160.0p</td>
# ...

# %%
show(ft, 
     which = ['Ej', 'Isw', 'RoZF'],
     sort = 'Ej'
     )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ej</th>
#       <th>Isw</th>
#       <th>RoZF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>D059BBN2</th>
#       <td>77.3m</td>
#       <td>320.0f</td>
#       <td>236.7M</td>
#     </tr>
#     <tr>
#       <th>D059BBN2_n</th>
#       <td>104.2m</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>D059BBN8</th>
#       <td>114.2m</td>
#       <td>750.0f</td>
#       <td>50.0M</td>
#     </tr>
#     <tr>
#       <th>D0xxN5</th>
#       <td>135.5m</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>D062B3N2</th>
#       <td>136.4m</td>
#       <td>21.0p</td>
#       <td>4.3M</td>
#     </tr>
#     <tr>
#       <th>D060B2N6</th>
#       <td>203.9m</td>
#       <td>1.2p</td>
#       <td>22.9M</td>
#     </tr>
#     <tr>
#       <th>D060B2N2</th>
#       <td>226.1m</td>
#       <td>2.7p</td>
# ...

# %% [markdown]
# # Plotting

# %% [markdown]
# ## as pd method

# %%
ax = ft.plot(x = 'RoZF', y = 'Isw', marker = 'o', ls = '')

ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# ## as plt method

# %%
fig, ax = plt.subplots()
ax.plot(ft['Isw'], ft['Isw']*ft['RoZF'], 'o')

ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# ## annotation

# %%
colormap = { 'D05' : 'C0', 'D06' : 'C1'}

ax = ft.plot( x = 'Rn_tot', y = 'Isw', color ='C1', marker = 'x', ls = '')

for dev_name in ft.index:
    dev = ft.loc[dev_name]
    ax.annotate( dev_name, ( dev['Rn_tot'], dev['Isw']), color = colormap.get(dev_name[:3], 'C4'))
    
ax.set_xscale('log')
ax.set_yscale('log')
