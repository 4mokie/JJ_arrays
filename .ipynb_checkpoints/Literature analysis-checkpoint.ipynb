# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as GridSpec
import numpy as np
import pandas as pd

import os

from IPython.core.display import display, HTML
from JJformulas import *

# %%
dropbox_folder = "E:\\Dropbox\\phase%20diffusion"

# %% [markdown]
# Attempt to summarize all avaliable data on small Josephson junctions, single or array-ed

# %% [markdown]
#  # Jack's thesis

# %%
filename =  '\\Jack%20phd%20-%20Josephson%20Tunneling%20at%20the%20Atomic%20Scale%20The%20Josephson%20Eect%20as%20a%20Local%20Probe(4).pdf'
display(HTML('<a target="_blank" href={}>{}</a>'.format(dropbox_folder+filename,'dropbox pdf')))

filename =  'https://www.fkf.mpg.de/5659827/dok95-Jaeck-Bert-epfl.pdf'
display(HTML('<a target="_blank" href={}>{}</a>'.format(filename,'online pdf')))
# Out:
# <a target="_blank" href=E:\Dropbox\phase%20diffusion\Jack%20phd%20-%20Josephson%20Tunneling%20at%20the%20Atomic%20Scale%20The%20Josephson%20Eect%20as%20a%20Local%20Probe(4).pdf>dropbox pdf</a>
# <a target="_blank" href=https://www.fkf.mpg.de/5659827/dok95-Jaeck-Bert-epfl.pdf>online pdf</a>

# %% [markdown]
# p42
# ![image.png](attachment:image.png)

# %% [markdown]
# if we trust this guy, EJ (K) = xGn(Go)

# %% [markdown]
# ## p43

# %% [markdown]
# Ej =
# Ec =
# Isw =

# %% [markdown]
# p43
#
# ![image.png](attachment:image.png)

# %%
Gn = 1
