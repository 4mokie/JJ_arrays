# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt


from scipy import *
from scipy import optimize

from wavefunction1d import *


from matplotlib.gridspec import GridSpec,  GridSpecFromSubplotSpec

from Ejcos import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b9ec6d401637> in <module>
#       6 from scipy import optimize
#       7
# ----> 8 from wavefunction1d import *
#       9
#      10
#
# ModuleNotFoundError: No module named 'wavefunction1d'

# %%
plot_Ejcos(Ej = 1.000, Ec = .05, N = 6, ib = 0.011/8.2)
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
def plot_Ejcos(Ej, Ec, N, ib):
    
    
    
    ng_list = np.linspace(-1, 1, 101)

    fig, ax = plt.subplots()
     
    ax.plot(ng_list, Ej*np.cos(ng_list*2*np.pi + np.pi )- Ej*ib*ng_list*2*np.pi )
    
    Es = get_CPB_spec(Ej = Ej, Ec = Ec, ng_list = ng_list)
    
    for i in range(N):
        
        Emax, Emin = max(Es[:,i]), min(Es[:,i])
        ax.fill_between(ng_list, Emax, Emin, alpha = 0.3)
        ax.hlines(Emax,-1,1, alpha = 0.3, color = f'C{i}')
        ax.hlines(Emin,-1,1, alpha = 0.3, color = f'C{i}')
    

    wp = np.sqrt(8*Ej*Ec)
    
    ax.set_title('Ej = {:1.2f}, Ec = {:1.3f}, wp = {:1.2f}'.format(Ej,Ec,wp) )
#     print('Ej = {:1.2f}, Ec = {:1.2f}, wp = {:1.2f}'.format(Ej,Ec,wp))
    return ax
